# %%
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
df = pd.read_csv(r'C:\Users\matth\PhD\Fall 2024\SSIE 501-SSE 440\Programming\ScrapingOutput\DataCollector4\blackbox_1.csv')

# %%
average_entropy = pd.DataFrame([row], columns=titlecol)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 average_entropy = pd.DataFrame([row], columns=titlecol)
#
# NameError: name 'row' is not defined

# %%
entropy_at_step = []
for i in range(0,df.shape[0]):
    row = df.iloc[i,1:]
    prob_x=0 
    unique_value_counts = row.value_counts()
    for value, count in unique_value_counts.items():
        prob_x = prob_x - (count/400) * (math.log2(count/400))
    entropy_at_step.append(prob_x)

# %%
df_first = pd.read_csv(r'C:\Users\matth\PhD\Fall 2024\SSIE 501-SSE 440\Programming\ScrapingOutput\DataCollector4\blackbox_0.csv')

n_time_steps = df_first.shape[0] 
entropy_at_step = [0] * n_time_steps 

for df_counter in range(0, 100):
    df = pd.read_csv(r'C:\Users\matth\PhD\Fall 2024\SSIE 501-SSE 440\Programming\ScrapingOutput\DataCollector4\blackbox_'+str(df_counter)+'.csv')
    for i in range(0, df.shape[0]):
        row = df.iloc[i, 1:]
        prob_x = 0 
        unique_value_counts = row.value_counts()
        for value, count in unique_value_counts.items():
            prob_x = prob_x - (count/400) * (math.log2(count/400))
        entropy_at_step[i] += prob_x  # Accumulate entropy; averaging will happen later

entropy_at_step = [entropy / 101 for entropy in entropy_at_step]  # Averaging over 101 files

# Now entropy_at_step contains the average entropy for each time step across all files
print(entropy_at_step)  # Or plot the result if needed
# Out:
# [3.271806853398166, 3.271691171331912, 3.2714117608843525, 3.2711792425892794, 3.2707968303286608, 3.270421343069455, 3.270408300109114, 3.2701064685981507, 3.269900187582474, 3.269609969636765, 3.269039420766075, 3.2686602050551143, 3.2682134671746255, 3.267483016865495, 3.266739854186024, 3.266441318425288, 3.265963265885994, 3.2653614236444137, 3.2647484008648013, 3.2638213196837467, 3.263247117480277, 3.2627330508329253, 3.2621766635826, 3.2615452110819065, 3.260594868316715, 3.2600544200561092, 3.259095449866727, 3.2584318661460454, 3.2574518243061137, 3.2568089240369216, 3.2559803089131245, 3.2547899015208794, 3.2537662466873134, 3.2527548252160177, 3.251590111146909, 3.2505691586206695, 3.249718718028678, 3.2488235806148444, 3.2478914705618607, 3.247050619473548, 3.246283065573358, 3.24518611757494, 3.2441620221839926, 3.2429646314878604, 3.242317637850624, 3.2412496335008236, 3.239950643211962, 3.239169076097017, 3.2381208526028713, 3.236819577166892, 3.235724450047826, 3.234
# ...

# %%
plt.figure(figsize=(10, 6))
plt.xlabel('Step In Time')
plt.ylabel('Shannon Entropy')
plt.title('Entire Black Box Over 100 Runs')
x_values=list(range(0,2000))
y_values=entropy_at_step[0:2000]
plt.plot(x_values, y_values, label='Y Values',color='purple')
plt.show()

# %%
df_first = pd.read_csv(r'C:\Users\matth\PhD\Fall 2024\SSIE 501-SSE 440\Programming\ScrapingOutput\DataCollector4\blackbox_0.csv')

n_time_steps = df_first.shape[0] 
entropy_at_step_q2 = [0] * n_time_steps 

for df_counter in range(0, 100):
    df = pd.read_csv(r'C:\Users\matth\PhD\Fall 2024\SSIE 501-SSE 440\Programming\ScrapingOutput\DataCollector4\blackbox_'+str(df_counter)+'.csv')
    for i in range(0, df.shape[0]):
        row = df.iloc[i, 1:101]
        prob_x = 0 
        unique_value_counts = row.value_counts()
        for value, count in unique_value_counts.items():
            prob_x = prob_x - (count/len(row)) * (math.log2(count/len(row)))
        entropy_at_step_q2[i] += prob_x  # Accumulate entropy; averaging will happen later

entropy_at_step_q2 = [entropy / 101 for entropy in entropy_at_step_q2]  # Averaging over 101 files

plt.figure(figsize=(10, 6))
plt.xlabel('Step In Time')
plt.ylabel('Shannon Entropy for 100 Runs')
plt.title('Q2')
x_values=list(range(0,2000))
y_values=entropy_at_step_q2[0:2000]
plt.plot(x_values, y_values, label='Y Values')
plt.show()

# %%
df_first = pd.read_csv(r'C:\Users\matth\PhD\Fall 2024\SSIE 501-SSE 440\Programming\ScrapingOutput\DataCollector4\blackbox_0.csv')

n_time_steps = df_first.shape[0] 
entropy_at_step_q1 = [0] * n_time_steps 

for df_counter in range(0, 100):
    df = pd.read_csv(r'C:\Users\matth\PhD\Fall 2024\SSIE 501-SSE 440\Programming\ScrapingOutput\DataCollector4\blackbox_'+str(df_counter)+'.csv')
    for i in range(0, df.shape[0]):
        row = df.iloc[i, 101:201]
        prob_x = 0 
        unique_value_counts = row.value_counts()
        for value, count in unique_value_counts.items():
            prob_x = prob_x - (count/len(row)) * (math.log2(count/len(row)))
        entropy_at_step_q1[i] += prob_x  # Accumulate entropy; averaging will happen later

entropy_at_step_q1 = [entropy / 101 for entropy in entropy_at_step_q1]  # Averaging over 101 files

plt.figure(figsize=(10, 6))
plt.xlabel('Step In Time')
plt.ylabel('Shannon Entropy for 100 Runs')
plt.title('Q1')
x_values=list(range(0,2000))
y_values=entropy_at_step_q1[0:2000]
plt.plot(x_values, y_values, label='Y Values')
plt.show()

# %%
df_first = pd.read_csv(r'C:\Users\matth\PhD\Fall 2024\SSIE 501-SSE 440\Programming\ScrapingOutput\DataCollector4\blackbox_0.csv')

n_time_steps = df_first.shape[0] 
entropy_at_step_q3 = [0] * n_time_steps 

for df_counter in range(0, 100):
    df = pd.read_csv(r'C:\Users\matth\PhD\Fall 2024\SSIE 501-SSE 440\Programming\ScrapingOutput\DataCollector4\blackbox_'+str(df_counter)+'.csv')
    for i in range(0, df.shape[0]):
        row = df.iloc[i, 201:301]
        prob_x = 0 
        unique_value_counts = row.value_counts()
        for value, count in unique_value_counts.items():
            prob_x = prob_x - (count/len(row)) * (math.log2(count/len(row)))
        entropy_at_step_q3[i] += prob_x  # Accumulate entropy; averaging will happen later

entropy_at_step_q3 = [entropy / 101 for entropy in entropy_at_step_q3]  # Averaging over 101 files

plt.figure(figsize=(10, 6))
plt.xlabel('Step In Time')
plt.ylabel('Shannon Entropy for 100 Runs')
plt.title('Q3')
x_values=list(range(0,2000))
y_values=entropy_at_step_q3[0:2000]
plt.plot(x_values, y_values, label='Y Values')
plt.show()

# %%
df_first = pd.read_csv(r'C:\Users\matth\PhD\Fall 2024\SSIE 501-SSE 440\Programming\ScrapingOutput\DataCollector4\blackbox_0.csv')

n_time_steps = df_first.shape[0] 
entropy_at_step_q4 = [0] * n_time_steps 

for df_counter in range(0, 100):
    df = pd.read_csv(r'C:\Users\matth\PhD\Fall 2024\SSIE 501-SSE 440\Programming\ScrapingOutput\DataCollector4\blackbox_'+str(df_counter)+'.csv')
    for i in range(0, df.shape[0]):
        row = df.iloc[i, 301:401]
        prob_x = 0 
        unique_value_counts = row.value_counts()
        for value, count in unique_value_counts.items():
            prob_x = prob_x - (count/len(row)) * (math.log2(count/len(row)))
        entropy_at_step_q4[i] += prob_x  # Accumulate entropy; averaging will happen later

entropy_at_step_q4 = [entropy / 101 for entropy in entropy_at_step_q4]  # Averaging over 101 files

plt.figure(figsize=(10, 6))
plt.xlabel('Step In Time')
plt.ylabel('Shannon Entropy for 100 Runs')
plt.title('Q4')
x_values=list(range(0,2000))
y_values=entropy_at_step_q4[0:2000]
plt.plot(x_values, y_values, label='Y Values')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.tick_params(labeltop=False, labelright=True)
plt.xlabel('Step In Time')
plt.ylabel('Shannon Entropy')
plt.title('Average Shannon Entropy for 100 Runs - Quadrants')

x_values=list(range(0,2000))

plt.plot(x_values, entropy_at_step_q1[0:2000], label='Q1')
plt.plot(x_values, entropy_at_step_q2[0:2000], label='Q2')
plt.plot(x_values, entropy_at_step_q3[0:2000], label='Q3')
plt.plot(x_values, entropy_at_step_q4[0:2000], label='Q4')
plt.legend()
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
