# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\matth\PhD\Fall 2024\SSIE 501-SSE 440\Programming\ScrapingOutput\DataCollector4\blackbox_0.csv')
#df.head

# %%
cols_needed = []
for i in range(0,100):
    cols_needed.append('Q1-pos'+str(i))

dfQ1 = df[cols_needed]
dfQ1.head()
# Out:
#   Q1-pos0 Q1-pos1 Q1-pos2 Q1-pos3 Q1-pos4 Q1-pos5 Q1-pos6 Q1-pos7 Q1-pos8  \
# 0     mex     gru     mex     las     pty     gru     gru     pty     lis
# 1     mex     gru     mex     las     pty     gru     gru     pty     lis
# 2     mex     gru     mex     las     pty     gru     gru     pty     lis
# 3     mex     gru     mex     las     pty     gru     gru     pty     lis
# 4     mex     gru     mex     las     pty     gru     gru     pty     lis
#
#   Q1-pos9  ... Q1-pos90 Q1-pos91 Q1-pos92 Q1-pos93 Q1-pos94 Q1-pos95 Q1-pos96  \
# 0     las  ...      hkg      bru      gru      jfk      jfk      pty      pty
# 1     las  ...      hkg      bru      gru      jfk      jfk      pty      pty
# 2     las  ...      hkg      bru      gru      jfk      jfk      pty      pty
# 3     las  ...      hkg      bru      gru      jfk      jfk      pty      pty
# 4     las  ...      hkg      bru      gru      jfk      jfk      pty      pty
#
#   Q1-pos97 Q1-pos98 Q1-pos99
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 Q1-pos0 Q1-pos1 Q1-pos2 Q1-pos3 Q1-pos4 Q1-pos5 Q1-pos6 Q1-pos7  \
# 0           0     mex     gru     mex     las     pty     gru     gru     pty
# 1           1     mex     gru     mex     las     pty     gru     gru     pty
# 2           2     mex     gru     mex     las     pty     gru     gru     pty
# 3           3     mex     gru     mex     las     pty     gru     gru     pty
# 4           4     mex     gru     mex     las     pty     gru     gru     pty
#
#   Q1-pos8  ... Q4-pos390 Q4-pos391 Q4-pos392 Q4-pos393 Q4-pos394 Q4-pos395  \
# 0     lis  ...       mex       jfk       bru       hkg       hkg       gru
# 1     lis  ...       mex       jfk       bru       hkg       hkg       gru
# 2     lis  ...       mex       jfk       bru       hkg       hkg       las
# 3     lis  ...       mex       jfk       bru       hkg       hkg       las
# 4     lis  ...       mex       jfk       bru       hkg       hkg       las
#
#   Q4-pos396 Q4-pos397 Q4-pos398 Q4-pos399
# ...

# %%
yourdf1 = dfQ1[dfQ1[cols_needed].nunique(axis=1) == 1]
steps_to_get_black = 2000-yourdf1.shape[0]

# %%
steps_to_get_black
# Out:
# 1318

# %%
x_axis = df.iloc[:,0]
plt.plot(x_axis, df['Q3-pos213'], label='Comparison 1')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Matplotlib Comparison Plot')
# Out:
# Text(0.5, 1.0, 'Matplotlib Comparison Plot')

# %%
df.head()
count_gru_ic = []
for i in range(0,400,100):
    row_chunk  = df.iloc[0,i:i+100]
    count_gru = row_chunk.astype(str).str.contains('gru').sum()
    count_gru_ic.append(count_gru)
print(count_gru_ic)
# Out:
# [11, 13, 14, 12]

# %%
steps_to_get_black
# Out:
# 1318

# %%
labels = ['Q1','Q2','Q3','Q4']
fig, ax = plt.subplots()
ax.bar(labels, count_gru_ic, color=['blue', 'orange', 'green', 'red'])
ax.set_ylabel('Count of "gru"')
ax.set_title('Stacked Bar Chart for "gru" Count by Column Range')
plt.show()
