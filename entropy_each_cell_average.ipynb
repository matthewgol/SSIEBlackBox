# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\matth\PhD\Fall 2024\SSIE 501-SSE 440\Programming\ScrapingOutput\DataCollector4\blackbox_1.csv')

# %%
col = df.iloc[:,1]

# %%
unique_value_counts = col.value_counts()

# %%
sum_of_steps = unique_value_counts.sum()
entropy=0
entropies = []

for i in range(1,401):
    col = df.iloc[:,i]
    unique_value_counts = col.value_counts()
    for value,count in unique_value_counts.items():
        #print(count)
        entropy= entropy - ((count/sum_of_steps) * math.log2(count/sum_of_steps))
        entropies.append(entropy)

# %%
entropy=0
entropies=[0] * 401
num_df = 1

for df_counter in range(0, num_df):
   df = pd.read_csv(r'C:\Users\matth\PhD\Fall 2024\SSIE 501-SSE 440\Programming\ScrapingOutput\DataCollector4\blackbox_'+str(df_counter)+'.csv')
   for i in range(1,401):
      col = df.iloc[:,i]
      unique_value_counts = col.value_counts()
      entropy=0
      for value,count in unique_value_counts.items():
         sum_of_steps = unique_value_counts.sum()
         entropy= entropy - (count/sum_of_steps) * math.log2(count/sum_of_steps)
      entropies[i-1] += (float(entropy))

entropies = [entropy/num_df for entropy in entropies]

print(entropies)
# Out:
# [0.9527564241230018, 0.0, 0.2889312549715477, 1.1630070215737065, 0.4793512324140561, 0.0, 0.0, 0.32134427526319154, 0.6256801997180159, 0.6159545640359803, 0.9304538767108219, 1.6799470817568298, 0.8116600684675142, 0.3913813628844628, 0.1968170983246084, 0.6620646249474866, 0.29580946352712234, 1.2251944154716814, 0.0, 0.9165186210113989, 0.9673100287095302, 0.6058808972687039, 0.30304010397932013, 0.6268937683059939, 0.5585414494434217, 0.1855883217945304, 0.0, 0.5374537627564357, 0.555887408282533, 0.5131729651522716, 0.9668547700250972, 1.1085545143673867, 1.2442125960143067, 0.5595255866670821, 0.615298273045265, 0.0, 0.4490958069213827, 0.6800845577026802, 0.4490483284543018, 0.550081321892119, 1.0599623815462433, 0.79214550567788, 0.5711182505450016, 1.0850690040928876, 1.0344261251957803, 0.7923356168805569, 0.8309641467341572, 0.0, 0.21398901970217202, 0.0, 0.0, 0.8434155414177639, 0.34539849643850457, 1.7327884543150387, 0.6190707685817451, 0.9277516777910448, 0.9247374378133466, 0.7625257605929561, 0.8739278484902655, 0.7478706747079182, 0.09690522484142772, 0.5012560857662114, 0.8820608498844706, 0.9208270219441159, 0.417694874931583, 2.2660387456936277, 0.10928571467638522, 1.0659060049856304, 0.7436793326896587, 0.14138441982563194, 0.6798802181402812, 0.2418812569675428, 0.7071173589385035, 0.5570975997372143, 0.3193373865339728, 0.6728799540738846, 0.4527881403447046, 0.2942476337570334, 0.6326102081121987, 0.13288058861622182, 0.2712376360678787, 0.28416371423224146, 0.5798428397869255, 0.20155902753861935, 0.9351099620576399, 0.2624586691894989, 0.0, 0.6066426286079917, 0.5248622647231557, 0.48669543934465487, 0.037606447550797284, 0.21879402256548452, 0.0, 0.7606420350268387, 0.35828696707266006, 0.6472527029561702, 1.0117721201348484, 0.45096116809480313, 0.6563654658110221, 0.4143762990787063, 2.343546742995494, 2.0113023415236078, 1.9021095373758632, 1.8704940580388751, 2.429083206440284, 1.8085197230821957, 2.2990718397360164, 1.984573062217916, 1.8901548582735508, 2.0159871659164357, 2.4603711130508286, 2.4830493155013427, 2.3963870088849877, 2.136443319939646, 2.5450730812910316, 2.5215131609028667, 1.841406493694348, 2.3874064233051198, 1.5335297562458048, 1.6192740466185498, 1.9173142495978077, 2.5332125010644777, 2.583681334955555, 2.274981184706749, 2.8885179023106304, 2.3351988243621835, 2.1189527847074645, 1.802540265891217, 2.123364757744997, 1.537280537849068, 2.100452212060112, 2.01765227798463, 2.299973028653734, 2.526361514061202, 2.267241743679369, 2.767018040663931, 2.442649024534582, 2.4919784711502775, 1.5719418765977398, 2.24796738378991, 1.8105725689515082, 2.3458546249187697, 2.804294761435481, 2.3045522396818363, 2.4404366874493744, 2.4022209284334024, 1.7480336259773928, 2.8314619754962145, 2.530224294187621, 1.818663345210544, 1.9970114122124905, 2.2752309656448713, 2.6336717115650723, 2.5205248640021285, 2.2660177041175706, 2.241142265584495, 2.22741480609036, 2.527284722066579, 1.9566885924454522, 2.4280867707665066, 2.477710879697497, 1.6880690347102125, 2.157606268887745, 2.185158665823899, 1.8850057526969812, 1.7895795796351426, 1.8243428077436767, 2.697133864975816, 2.2567837425207893, 2.5619310106532103, 2.0990176661676454, 2.037175821655849, 2.244541718316811, 1.9328185045851807, 2.6799213936871196, 2.433448160236995, 1.652023632030637, 2.2798257690204413, 2.588540664521039, 2.5135307333105645, 2.25260075544699, 2.081992269233216, 1.9664819602357269, 1.7959474301842768, 1.9949560718960813, 2.29044273282603, 2.267843309925296, 1.381226999661824, 2.2124929092102463, 2.4175325670231658, 1.6596433039586995, 2.341829826083302, 2.441614947406308, 2.4101999567717187, 1.8941209838416675, 2.1569068097256157, 2.199571977132492, 2.391583440885048, 2.094387271668527, 1.8864755733369076, 0.6040073603251629, 1.0089311517338784, 1.3342123085330047, 1.56512139486451, 1.1182789448538124, 1.9529084372307928, 2.2197169038589575, 2.209419948186828, 2.4524771150980014, 2.027868519393673, 0.704 ...

# %%
data_100 = entropies[:100]
data_200 = entropies[100:200]
data_300 = entropies[200:300]
data_400 = entropies[300:400]



q1 = np.reshape(data_100,(10,10))
q2 = np.reshape(data_200,(10,10))
q3 = np.reshape(data_300,(10,10))
q4 = np.reshape(data_400,(10,10))

# %%
figure,axis = plt.subplots(2,2, figsize=(9,9))
plt.figure(figsize=(8, 8))
sns.heatmap(q1, annot=True, fmt=".1f", cmap="Blues", ax=axis[0,1],  vmin=0, vmax=3)
axis[0,1].set_title("Q2")
sns.heatmap(q2, annot=True, fmt=".1f", cmap="Blues", ax=axis[0,0], vmin=0, vmax=3)
axis[0,0].set_title("Q1")
sns.heatmap(q3, annot=True, fmt=".1f", cmap="Blues", ax=axis[1,0], vmin=0, vmax=3)
axis[1,0].set_title("Q3")
sns.heatmap(q4, annot=True, fmt=".1f", cmap="Blues",  ax=axis[1,1], vmin=0, vmax=3)
axis[1,1].set_title("Q4")
figure.suptitle("Entropy for Every Cell in the Matrix for One Run")
plt.show()

# %%
data_100 = entropies[:100]
data_200 = entropies[100:200]
data_300 = entropies[200:300]
data_400 = entropies[300:400]

data = data_200 + data_100 + data_300 + data_400


matrix = np.reshape(data,(20,20))
matrix
plt.figure(figsize=(8, 8))
sns.heatmap(matrix, annot=True, fmt=".1f", cmap="Blues", cbar=True)
plt.show()

# %%
entropy=0
entropies=[0] * 401
num_df = 100

for df_counter in range(0, num_df):
   df = pd.read_csv(r'C:\Users\matth\PhD\Fall 2024\SSIE 501-SSE 440\Programming\ScrapingOutput\DataCollector4\blackbox_'+str(df_counter)+'.csv')
   for i in range(1,401):
      col = df.iloc[:,i]
      unique_value_counts = col.value_counts()
      entropy=0
      for value,count in unique_value_counts.items():
         sum_of_steps = unique_value_counts.sum()
         entropy= entropy - (count/sum_of_steps) * math.log2(count/sum_of_steps)
      entropies[i-1] += (float(entropy))

entropies = [entropy/num_df for entropy in entropies]

print(entropies)
# Out:
# [0.5769541110248485, 0.5613246492157546, 0.5912496330322008, 0.5833667195068081, 0.5530675063486948, 0.5163556168553127, 0.4901021479251082, 0.4924874124366815, 0.5711272477248509, 0.5931327913589858, 0.5669407559967713, 0.5788805446788092, 0.576730815215259, 0.5521998609624584, 0.5336209610502342, 0.5798226486519021, 0.49436771059512113, 0.5185842422163315, 0.5593433069891353, 0.6096835840043794, 0.5727632757024173, 0.5895496997439301, 0.548604490756687, 0.5961607741914778, 0.5753333278466805, 0.5645627094798689, 0.5273158754752489, 0.6293015106327424, 0.4470630986250817, 0.6014800819419239, 0.5561298513561639, 0.6207206708001497, 0.5627931400393038, 0.8961734130666278, 0.8547570478484333, 0.9546232414577415, 0.874347959165638, 0.5641186115600232, 0.6112944366590637, 0.5145382072195364, 0.5452630048904489, 0.5216013540612735, 0.5686667912826463, 0.7676273933292314, 0.8326210523904407, 0.7651551662003329, 0.8770491782732317, 0.5436768890932495, 0.5863462530444112, 0.5682871678456216, 0.5490107726673376, 0.5310636003751379, 0.5530009092225824, 0.9131063123618075, 0.8245208993659798, 0.9015883021230848, 0.8983916907433547, 0.507221138166463, 0.576150367083898, 0.5286015713396751, 0.5667793362744177, 0.5271181910452711, 0.5750401774244951, 0.8422526096506456, 0.7769621515402291, 0.8527899496194196, 0.8100361865002621, 0.5022834093206066, 0.5427902527750208, 0.5276689078089486, 0.5565084076014742, 0.6081643961787497, 0.5400034132697599, 0.5610400133724528, 0.5055318526827944, 0.5482077797831763, 0.5910474005187524, 0.5763153647459283, 0.6245643458262137, 0.5734838132406321, 0.5824146385703461, 0.512359773548648, 0.5907799324010177, 0.5187041198384944, 0.5668287431339543, 0.5983884162043775, 0.5494998986069352, 0.5076570091400198, 0.5190119220609163, 0.6076725695881914, 0.5162535172116509, 0.585226107438898, 0.6021769791142981, 0.4817651908612542, 0.5501650716660925, 0.5262704086419698, 0.5700353889230092, 0.5358329800745368, 0.5833815589681939, 0.5290172917228217, 2.162633125428789, 2.1641958960340886, 2.157654046585816, 2.1856456277346332, 2.204139041916849, 2.2005925883939845, 2.1461213683889575, 2.1361457239141735, 2.2114807797365867, 2.132599747483234, 2.1783220686273035, 2.1386275543620923, 2.173035732468381, 2.2043366493507586, 2.1843866033634822, 2.2763888576070346, 2.231433414744111, 2.1738827907641975, 2.1693580210038137, 2.1786281550487425, 2.2400782462782916, 2.1888581938432425, 2.1956626317235104, 2.2130076148277187, 2.2451848243412384, 2.2409480492586287, 2.233500865957031, 2.1720296769036525, 2.166238093746117, 2.238777403287666, 2.170142931307614, 2.2523361603100858, 2.1577769003466565, 2.2496173492013605, 2.186070579567078, 2.255305447791707, 2.1805592566233902, 2.214572456312068, 2.2249430405816883, 2.18246091924368, 2.156119750096733, 2.232292735349513, 2.182762650550747, 2.1956439808894617, 2.248601930415093, 2.16813077878884, 2.15239495591934, 2.167612053873807, 2.1445440182531517, 2.244034672534961, 2.20488304209724, 2.1522448827997938, 2.175936676534023, 2.2261172758577685, 2.1960424800775793, 2.2206123521324677, 2.221635642962618, 2.1204613606180533, 2.1856178374524604, 2.1356980903453406, 2.258391829055811, 2.201024124200421, 2.1939293480240405, 2.1932418562909195, 2.148054339567028, 2.194539337522376, 2.1948090682419514, 2.1632725277325235, 2.1305118270066083, 2.1336189395436036, 2.172298446631132, 2.198844679691101, 2.179626009862503, 2.2280411940042035, 2.1411810559825146, 2.243394513288475, 2.1313254829128208, 2.209729292799637, 2.1690959405723396, 2.197149870489792, 2.158041996648521, 2.1849727472005, 2.171331760113143, 2.1658064488753483, 2.2075459274572804, 2.179942172406061, 2.1709566578857484, 2.1534246338051846, 2.235717130913894, 2.2399755137084387, 2.2075937317351086, 2.2322835268718113, 2.1719111190103053, 2.163813142836012, 2.168667277544428, 2.2116295447822183, 2.2499834281179667, 2.224544041685887, 2.2022860091471728, 2.2242675938601493, 1.3843131001313427, 1.3841754689639187, 1.399243136937 ...

# %%
data_100 = entropies[:100]
data_200 = entropies[100:200]
data_300 = entropies[200:300]
data_400 = entropies[300:400]



q1 = np.reshape(data_100,(10,10))
q2 = np.reshape(data_200,(10,10))
q3 = np.reshape(data_300,(10,10))
q4 = np.reshape(data_400,(10,10))

# %%
figure,axis = plt.subplots(2,2, figsize=(9.5,9.5))
plt.figure(figsize=(8, 8))
sns.heatmap(q1, annot=True, fmt=".1f", cmap="Blues", ax=axis[0,1], vmin=0, vmax=3)
axis[0,1].set_title("Q2")
sns.heatmap(q2, annot=True, fmt=".1f", cmap="Blues", ax=axis[0,0], vmin=0, vmax=3)
axis[0,0].set_title("Q1")
sns.heatmap(q3, annot=True, fmt=".1f", cmap="Blues", ax=axis[1,0], vmin=0, vmax=3)
axis[1,0].set_title("Q3")
sns.heatmap(q4, annot=True, fmt=".1f", cmap="Blues",  ax=axis[1,1], vmin=0, vmax=3)
axis[1,1].set_title("Q4")
figure.suptitle("Entropy for Every Cell in the Matrix for One Run")
plt.show()
