# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\matth\PhD\Fall 2024\SSIE 501-SSE 440\Programming\ScrapingOutput\DataCollector4\blackbox_1.csv')

# %%
col = df.iloc[:,1]

# %%
unique_value_counts = col.value_counts()

# %%
sum_of_steps = unique_value_counts.sum()
entropy=0
entropies = []

for i in range(1,401):
    col = df.iloc[:,i]
    unique_value_counts = col.value_counts()
    for value,count in unique_value_counts.items():
        #print(count)
        entropy= entropy - ((count/sum_of_steps) * math.log2(count/sum_of_steps))
        entropies.append(entropy)

# %%
entropy=0
entropies=[]
for i in range(1,401):
    col = df.iloc[:,i]
    print(col)
    unique_value_counts = col.value_counts()
    entropy=0
    for value,count in unique_value_counts.items():
       #print(f'count is {count}')
       sum_of_steps = unique_value_counts.sum()
       #print(f'sum of steps is {sum_of_steps}')
       entropy= entropy - (count/sum_of_steps) * math.log2(count/sum_of_steps)
    #print(entropy)
    entropies.append(float(entropy))
# Out:
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos0, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos1, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos2, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos3, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos4, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos5, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos6, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos7, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos8, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos9, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos10, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos11, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos12, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos13, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos14, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos15, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos16, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos17, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos18, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos19, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos20, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos21, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos22, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos23, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos24, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos25, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos26, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos27, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos28, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos29, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos30, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos31, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos32, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos33, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos34, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos35, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos36, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos37, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos38, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos39, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos40, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos41, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos42, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos43, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos44, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos45, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos46, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos47, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos48, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos49, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos50, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos51, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos52, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos53, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos54, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos55, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos56, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos57, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos58, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos59, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos60, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos61, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos62, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos63, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos64, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos65, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos66, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos67, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos68, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos69, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos70, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos71, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos72, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos73, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos74, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos75, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos76, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos77, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos78, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos79, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos80, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos81, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos82, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos83, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos84, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos85, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos86, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos87, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos88, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos89, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos90, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos91, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos92, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos93, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos94, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos95, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos96, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos97, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos98, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q1-pos99, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos100, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    lax
# 1997    lax
# 1998    lax
# 1999    lax
# 2000    lax
# Name: Q2-pos101, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos102, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    pty
# 1997    pty
# 1998    pty
# 1999    pty
# 2000    pty
# Name: Q2-pos103, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q2-pos104, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    lax
# 1997    lax
# 1998    lax
# 1999    lax
# 2000    lax
# Name: Q2-pos105, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q2-pos106, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    jfk
# 1997    jfk
# 1998    jfk
# 1999    jfk
# 2000    jfk
# Name: Q2-pos107, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    las
# 1997    las
# 1998    las
# 1999    las
# 2000    las
# Name: Q2-pos108, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos109, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos110, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos111, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos112, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos113, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    bru
# 1997    bru
# 1998    bru
# 1999    bru
# 2000    bru
# Name: Q2-pos114, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    pty
# 1997    pty
# 1998    pty
# 1999    pty
# 2000    pty
# Name: Q2-pos115, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q2-pos116, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    pty
# 1997    pty
# 1998    pty
# 1999    pty
# 2000    gru
# Name: Q2-pos117, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos118, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    jfk
# 1997    jfk
# 1998    jfk
# 1999    jfk
# 2000    jfk
# Name: Q2-pos119, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q2-pos120, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    jfk
# 1997    jfk
# 1998    jfk
# 1999    jfk
# 2000    jfk
# Name: Q2-pos121, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    pty
# 1997    pty
# 1998    pty
# 1999    pty
# 2000    pty
# Name: Q2-pos122, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    jfk
# 1997    jfk
# 1998    jfk
# 1999    jfk
# 2000    jfk
# Name: Q2-pos123, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    pty
# 1997    pty
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos124, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos125, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q2-pos126, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q2-pos127, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q2-pos128, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    pty
# 1997    pty
# 1998    pty
# 1999    pty
# 2000    pty
# Name: Q2-pos129, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    jfk
# 1997    jfk
# 1998    jfk
# 1999    jfk
# 2000    jfk
# Name: Q2-pos130, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos131, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    jfk
# 1997    jfk
# 1998    jfk
# 1999    jfk
# 2000    jfk
# Name: Q2-pos132, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos133, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos134, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    pty
# 1997    pty
# 1998    pty
# 1999    pty
# 2000    pty
# Name: Q2-pos135, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    pty
# 1997    pty
# 1998    pty
# 1999    las
# 2000    las
# Name: Q2-pos136, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q2-pos137, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos138, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    pty
# 1997    pty
# 1998    pty
# 1999    pty
# 2000    pty
# Name: Q2-pos139, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos140, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    pty
# 1997    pty
# 1998    pty
# 1999    pty
# 2000    pty
# Name: Q2-pos141, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    jfk
# 1997    jfk
# 1998    jfk
# 1999    jfk
# 2000    jfk
# Name: Q2-pos142, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q2-pos143, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    jfk
# 1997    jfk
# 1998    jfk
# 1999    jfk
# 2000    jfk
# Name: Q2-pos144, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos145, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q2-pos146, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    bru
# 1997    bru
# 1998    bru
# 1999    bru
# 2000    bru
# Name: Q2-pos147, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos148, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos149, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos150, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos151, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos152, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos153, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    pty
# 1997    pty
# 1998    pty
# 1999    pty
# 2000    pty
# Name: Q2-pos154, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    las
# 1997    las
# 1998    las
# 1999    las
# 2000    las
# Name: Q2-pos155, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    jfk
# 1997    jfk
# 1998    jfk
# 1999    jfk
# 2000    jfk
# Name: Q2-pos156, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    las
# 1997    las
# 1998    las
# 1999    las
# 2000    las
# Name: Q2-pos157, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    las
# 1997    las
# 1998    las
# 1999    las
# 2000    las
# Name: Q2-pos158, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    pty
# 1997    pty
# 1998    pty
# 1999    pty
# 2000    pty
# Name: Q2-pos159, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos160, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos161, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q2-pos162, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q2-pos163, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos164, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    pty
# 1997    pty
# 1998    pty
# 1999    pty
# 2000    pty
# Name: Q2-pos165, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q2-pos166, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos167, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos168, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    pty
# 1997    pty
# 1998    pty
# 1999    pty
# 2000    pty
# Name: Q2-pos169, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q2-pos170, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    las
# 1997    las
# 1998    las
# 1999    las
# 2000    las
# Name: Q2-pos171, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       gru
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q2-pos172, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    lax
# 1997    lax
# 1998    lax
# 1999    lax
# 2000    lax
# Name: Q2-pos173, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos174, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    pty
# 1997    pty
# 1998    pty
# 1999    pty
# 2000    pty
# Name: Q2-pos175, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    gru
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q2-pos176, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    pty
# 1997    pty
# 1998    pty
# 1999    pty
# 2000    pty
# Name: Q2-pos177, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q2-pos178, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    pty
# 1997    pty
# 1998    pty
# 1999    pty
# 2000    pty
# Name: Q2-pos179, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    pty
# 1997    pty
# 1998    pty
# 1999    pty
# 2000    pty
# Name: Q2-pos180, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    pty
# 1997    pty
# 1998    pty
# 1999    pty
# 2000    pty
# Name: Q2-pos181, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    bru
# 1997    bru
# 1998    bru
# 1999    bru
# 2000    bru
# Name: Q2-pos182, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos183, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    las
# 1997    las
# 1998    las
# 1999    las
# 2000    las
# Name: Q2-pos184, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q2-pos185, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos186, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos187, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    bru
# 1997    bru
# 1998    bru
# 1999    bru
# 2000    bru
# Name: Q2-pos188, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos189, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos190, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    jfk
# 1997    jfk
# 1998    jfk
# 1999    jfk
# 2000    jfk
# Name: Q2-pos191, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q2-pos192, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q2-pos193, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    jfk
# 1997    jfk
# 1998    jfk
# 1999    jfk
# 2000    jfk
# Name: Q2-pos194, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    jfk
# 1997    jfk
# 1998    jfk
# 1999    jfk
# 2000    jfk
# Name: Q2-pos195, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    pty
# 1997    pty
# 1998    pty
# 1999    pty
# 2000    pty
# Name: Q2-pos196, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       jfk
# 4       jfk
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q2-pos197, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    pty
# 1997    pty
# 1998    pty
# 1999    pty
# 2000    pty
# Name: Q2-pos198, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    jfk
# 1997    jfk
# 1998    jfk
# 1999    jfk
# 2000    jfk
# Name: Q2-pos199, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q3-pos200, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q3-pos201, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q3-pos202, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q3-pos203, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q3-pos204, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q3-pos205, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q3-pos206, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q3-pos207, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q3-pos208, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q3-pos209, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q3-pos210, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q3-pos211, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q3-pos212, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q3-pos213, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q3-pos214, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    bru
# 1997    bru
# 1998    bru
# 1999    bru
# 2000    bru
# Name: Q3-pos215, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    bru
# 1997    bru
# 1998    bru
# 1999    bru
# 2000    bru
# Name: Q3-pos216, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    bru
# 1997    bru
# 1998    bru
# 1999    bru
# 2000    bru
# Name: Q3-pos217, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q3-pos218, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q3-pos219, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos220, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos221, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       lis
# 4       lis
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q3-pos222, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q3-pos223, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q3-pos224, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    bru
# 1997    bru
# 1998    bru
# 1999    bru
# 2000    bru
# Name: Q3-pos225, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q3-pos226, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    bru
# 1997    bru
# 1998    bru
# 1999    bru
# 2000    bru
# Name: Q3-pos227, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q3-pos228, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q3-pos229, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos230, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos231, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q3-pos232, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos233, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos234, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q3-pos235, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q3-pos236, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    bru
# 1997    bru
# 1998    bru
# 1999    bru
# 2000    bru
# Name: Q3-pos237, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q3-pos238, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos239, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos240, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos241, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q3-pos242, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q3-pos243, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q3-pos244, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos245, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q3-pos246, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q3-pos247, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q3-pos248, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos249, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos250, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos251, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q3-pos252, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos253, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q3-pos254, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q3-pos255, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q3-pos256, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    bru
# 1997    bru
# 1998    bru
# 1999    bru
# 2000    bru
# Name: Q3-pos257, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q3-pos258, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       lis
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos259, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos260, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos261, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos262, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q3-pos263, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    bru
# 1997    bru
# 1998    bru
# 1999    bru
# 2000    bru
# Name: Q3-pos264, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q3-pos265, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    bru
# 1997    bru
# 1998    bru
# 1999    bru
# 2000    bru
# Name: Q3-pos266, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q3-pos267, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos268, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos269, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q3-pos270, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# ...
# 1999    las
# 2000    las
# Name: Q4-pos309, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q4-pos310, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q4-pos311, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q4-pos312, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q4-pos313, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q4-pos314, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q4-pos315, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q4-pos316, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q4-pos317, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q4-pos318, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q4-pos319, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q4-pos320, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q4-pos321, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos322, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos323, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos324, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos325, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos326, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos327, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q4-pos328, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos329, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos330, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    mex
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q4-pos331, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos332, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos333, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos334, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    jfk
# 1997    jfk
# 1998    jfk
# 1999    jfk
# 2000    jfk
# Name: Q4-pos335, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos336, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos337, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos338, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos339, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos340, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q4-pos341, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos342, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos343, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos344, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos345, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos346, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos347, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q4-pos348, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q4-pos349, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos350, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos351, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos352, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos353, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos354, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos355, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos356, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos357, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q4-pos358, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q4-pos359, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos360, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q4-pos361, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos362, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos363, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos364, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos365, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos366, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos367, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    gru
# 1997    gru
# 1998    gru
# 1999    gru
# 2000    gru
# Name: Q4-pos368, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q4-pos369, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q4-pos370, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q4-pos371, Length: 2001, dtype: object
# 0       pty
# 1       pty
# 2       pty
# 3       pty
# 4       pty
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos372, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos373, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos374, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       mex
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos375, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos376, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    mex
# 1997    mex
# 1998    mex
# 1999    mex
# 2000    mex
# Name: Q4-pos377, Length: 2001, dtype: object
# 0       hkg
# 1       hkg
# 2       hkg
# 3       hkg
# 4       hkg
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q4-pos378, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q4-pos379, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q4-pos380, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       mex
# 4       lis
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q4-pos381, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q4-pos382, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q4-pos383, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    hkg
# 1997    hkg
# 1998    hkg
# 1999    hkg
# 2000    hkg
# Name: Q4-pos384, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q4-pos385, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q4-pos386, Length: 2001, dtype: object
# 0       lis
# 1       lis
# 2       lis
# 3       lis
# 4       lis
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q4-pos387, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q4-pos388, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    icn
# 1997    icn
# 1998    icn
# 1999    icn
# 2000    icn
# Name: Q4-pos389, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q4-pos390, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    las
# 1997    las
# 1998    las
# 1999    las
# 2000    las
# Name: Q4-pos391, Length: 2001, dtype: object
# 0       las
# 1       las
# 2       las
# 3       las
# 4       las
#        ...
# 1996    las
# 1997    las
# 1998    las
# 1999    las
# 2000    las
# Name: Q4-pos392, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    las
# 1997    las
# 1998    las
# 1999    las
# 2000    las
# Name: Q4-pos393, Length: 2001, dtype: object
# 0       jfk
# 1       jfk
# 2       jfk
# 3       jfk
# 4       jfk
#        ...
# 1996    las
# 1997    las
# 1998    las
# 1999    las
# 2000    las
# Name: Q4-pos394, Length: 2001, dtype: object
# 0       mex
# 1       mex
# 2       mex
# 3       las
# 4       las
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q4-pos395, Length: 2001, dtype: object
# 0       gru
# 1       gru
# 2       gru
# 3       gru
# 4       gru
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q4-pos396, Length: 2001, dtype: object
# 0       bru
# 1       bru
# 2       bru
# 3       bru
# 4       bru
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q4-pos397, Length: 2001, dtype: object
# 0       lax
# 1       lax
# 2       lax
# 3       lax
# 4       lax
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q4-pos398, Length: 2001, dtype: object
# 0       icn
# 1       icn
# 2       icn
# 3       icn
# 4       icn
#        ...
# 1996    lis
# 1997    lis
# 1998    lis
# 1999    lis
# 2000    lis
# Name: Q4-pos399, Length: 2001, dtype: object

# %%
data_100 = entropies[:100]
data_200 = entropies[100:200]
data_300 = entropies[200:300]
data_400 = entropies[300:400]



q1 = np.reshape(data_100,(10,10))
q2 = np.reshape(data_200,(10,10))
q3 = np.reshape(data_300,(10,10))
q4 = np.reshape(data_400,(10,10))

# %%
figure,axis = plt.subplots(2,2, figsize=(10,10))
plt.figure(figsize=(8, 8))
sns.heatmap(q1, annot=True, fmt=".1f", cmap="Blues", ax=axis[0,1])
axis[0,1].set_title("Q1")
sns.heatmap(q2, annot=True, fmt=".1f", cmap="Blues", ax=axis[0,0])
axis[0,0].set_title("Q2")
sns.heatmap(q3, annot=True, fmt=".1f", cmap="Blues", ax=axis[1,0])
axis[1,0].set_title("Q3")
sns.heatmap(q4, annot=True, fmt=".1f", cmap="Blues",  ax=axis[1,1])
axis[1,1].set_title("Q4")
figure.suptitle("Entropy for Every Cell in the Matrix for One Run")
plt.show()

# %%
data_100 = entropies[:100]
data_200 = entropies[100:200]
data_300 = entropies[200:300]
data_400 = entropies[300:400]

data = data_200 + data_100 + data_300 + data_400


matrix = np.reshape(data,(20,20))
matrix
plt.figure(figsize=(8, 8))
sns.heatmap(matrix, annot=True, fmt=".1f", cmap="Blues", cbar=True)
plt.show()
